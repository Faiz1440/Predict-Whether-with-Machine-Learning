# %% [markdown]
# # Weather Forecasting

# %% [markdown]
# ## Importing the required libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("weatherHistory.csv")

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df[df.duplicated()].head()
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 36072  2010-08-02 00:00:00.000 +0200   Clear        rain        18.800000
# 36073  2010-08-02 01:00:00.000 +0200   Clear        rain        18.222222
# 36074  2010-08-02 02:00:00.000 +0200   Clear        rain        18.072222
# 36075  2010-08-02 03:00:00.000 +0200   Clear        rain        16.622222
# 36076  2010-08-02 04:00:00.000 +0200   Clear        rain        16.094444
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 36072                 18.800000      0.93             6.2790
# 36073                 18.222222      0.97             6.2790
# 36074                 18.072222      0.98            11.2700
# 36075                 16.622222      0.99             6.4400
# 36076                 16.094444      0.99             3.0751
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 36072                   270.0          14.9086         0.0
# ...

# %%
df.rename(columns = {'Precip Type':'Weather_type'}, inplace = True)

# %%
df1=df.drop(columns =['Summary', 'Loud Cover', 'Daily Summary'])

# %%
df1
# Out:
#                       Formatted Date Weather_type  Temperature (C)  \
# 0      2006-04-01 00:00:00.000 +0200         rain         9.472222
# 1      2006-04-01 01:00:00.000 +0200         rain         9.355556
# 2      2006-04-01 02:00:00.000 +0200         rain         9.377778
# 3      2006-04-01 03:00:00.000 +0200         rain         8.288889
# 4      2006-04-01 04:00:00.000 +0200         rain         8.755556
# ...                              ...          ...              ...
# 96448  2016-09-09 19:00:00.000 +0200         rain        26.016667
# 96449  2016-09-09 20:00:00.000 +0200         rain        24.583333
# 96450  2016-09-09 21:00:00.000 +0200         rain        22.038889
# 96451  2016-09-09 22:00:00.000 +0200         rain        21.522222
# 96452  2016-09-09 23:00:00.000 +0200         rain        20.438889
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                      7.388889      0.89            14.1197
# ...

# %%
df1.shape
# Out:
# (96453, 9)

# %%
df1.isnull().sum()
# Out:
# Formatted Date                0
# Weather_type                517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# dtype: int64

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# The column weather contains the data value in the string form and we need to predict the weather data so for that we need to process the data.

# %%
from sklearn.preprocessing import LabelEncoder

df1['Weather_type']=LabelEncoder().fit_transform(df1['Weather_type'])

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\faiza\AppData\Local\Temp\ipykernel_20676\3517735602.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # Machine Learning Model for Prediction of Weather...

# %%
from sklearn.model_selection import train_test_split
features=["Temperature (C)", "Apparent Temperature (C)", "Humidity", "Wind Speed (km/h)", "Wind Bearing (degrees)", "Visibility (km)", "Pressure (millibars)" ]
X=df1[features]
y=df1.Weather_type
train_X, test_X, train_y, test_y = train_test_split(X, y,random_state = 0)

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

model1=DecisionTreeRegressor(random_state=1)
model1.fit(train_X, train_y)
pred1=model1.predict(test_X)
print("Mean Absolute Error: %f" %(mean_absolute_error(test_y, pred1)))
# Out:
# Mean Absolute Error: 0.013021

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

model2=RandomForestRegressor(random_state=1)
model2.fit(train_X, train_y)
pred2=model2.predict(test_X)
print("Mean Absolute Error: %f" %(mean_absolute_error(test_y, pred2)))
# Out:
# Mean Absolute Error: 0.013623

# %% [markdown]
# ## Extreme Gradient Regressor

# %%
from xgboost import XGBRegressor

model3= XGBRegressor(n_estimators=100, learning_rate=0.04)
model3.fit(train_X, train_y)
pred3=model3.predict(test_X)
print("Mean Absolute Error: %f" %(mean_absolute_error(test_y, pred3)))
# Out:
# Mean Absolute Error: 0.023946

# %% [markdown]
# The least mean absolute error we got is of the Decision Tree Regressor Model.
